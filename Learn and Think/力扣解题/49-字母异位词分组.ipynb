# %% [markdown]
# 给你一个字符串数组，请你将 字母异位词 组合在一起。可以按任意顺序返回结果列表。
#
#
#
# 示例 1:
#
# 输入: strs = ["eat", "tea", "tan", "ate", "nat", "bat"]
#
# 输出: [["bat"],["nat","tan"],["ate","eat","tea"]]
#
# 解释：
#
# 在 strs 中没有字符串可以通过重新排列来形成 "bat"。
# 字符串 "nat" 和 "tan" 是字母异位词，因为它们可以重新排列以形成彼此。
# 字符串 "ate" ，"eat" 和 "tea" 是字母异位词，因为它们可以重新排列以形成彼此。
#
# 示例 2:
#
# 输入: strs = [""]
#
# 输出: [[""]]
#
# 示例 3:
#
# 输入: strs = ["a"]
#
# 输出: [["a"]]

# %%
strs = "hello world"
char_count = {}

for char in strs:
    if char in char_count:
        char_count[char] += 1
    else:
        char_count[char] = 1

print(char_count)
# 输出: {'h': 1, 'e': 1, 'l': 3, 'o': 2, ' ': 1, 'w': 1, 'r': 1, 'd': 1}
# Out:
# {'h': 1, 'e': 1, 'l': 3, 'o': 2, ' ': 1, 'w': 1, 'r': 1, 'd': 1}

# %%
# 第一次思考


from typing import List


class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:
        def statistics(str):
            char_count = {}
            for char in str:
                if char in char_count:
                    char_count[char] += 1
                else:
                    char_count[char] = 1
            return "+".join(f"{char}:{char_count[char]}" for char in sorted(char_count))  # 列表推导式

        result = {}
        for i, str in enumerate(strs):
            if statistics(str) in result:
                result[statistics(str)].append(i)
            else:
                result[statistics(str)] = [i]

        answer = []
        for value in result.values():
            answer.append([strs[i] for i in value])  # 列表推导式

        return answer


strs = ["eat", "tea", "tan", "ate", "nat", "bat"]

print(Solution().groupAnagrams(strs))
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %%
# 官方解法
import collections


class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:
        mp = collections.defaultdict(list)

        for st in strs:
            key = "".join(sorted(st))
            mp[key].append(st)

        return list(mp.values())


strs = ["eat", "tea", "tan", "ate", "nat", "bat"]

print(Solution().groupAnagrams(strs))
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]
